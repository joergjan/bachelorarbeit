# %% [markdown]
# ### jupyter notebook to adjust the data from onet to the Swiss labour market
#
# author: Jan Jörg
# date: 14.03.2024

# %% [markdown]
# ###### onet soc to soc crosswalk: https://www.onetcenter.org/crosswalks.html
# ###### soc to isco08 crosswalk: https://www.bls.gov/soc/ISCO_SOC_Crosswalk.xls
# ###### ch isco 19: https://www.i14y.admin.ch/en/catalog/datasets/HCL_CH_ISCO_19_PROF_1_2/distributions

# %%
# imports
import pandas as pd
from db import get_database

# %%
file_name =  "files/ONETSOC_SOC.xlsx"
sheet =  "ONETSOC_SOC"

onetsoc_soc = pd.read_excel(io=file_name, sheet_name=sheet , skiprows=3, dtype=str)

# rename cols
onetsoc_soc = onetsoc_soc.rename(columns={'O*NET-SOC 2019 Code': 'onetsoc19'})
onetsoc_soc = onetsoc_soc.rename(columns={'2018 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['O*NET-SOC 2019 Title', '2018 SOC Title']

# Drop specified columns
onetsoc_soc = onetsoc_soc.drop(columns=cols_to_drop)
onetsoc_soc = onetsoc_soc.dropna()
print(onetsoc_soc.shape[0])

onetsoc_soc.head(2)
# Out:
# 1016
#     onetsoc19  2010soc
# 0  11-1011.00  11-1011
# 1  11-1011.03  11-1011

# %%
file_name =  "files/ISCO_SOC.xls"
sheet =  "ISCO_SOC"

isco_soc = pd.read_excel(io=file_name, sheet_name=sheet , skiprows=6, dtype=str)

# rename cols
isco_soc = isco_soc.rename(columns={'ISCO-08 Code': 'isco08'})
isco_soc = isco_soc.rename(columns={'2010 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['ISCO-08 Title EN', 'part', '2010 SOC Title', "Comment 8/17/11"]

# Drop specified columns
isco_soc = isco_soc.drop(columns=cols_to_drop)
isco_soc = isco_soc.dropna()
print(isco_soc.shape[0])

isco_soc.head(2)
# Out:
# 1125
#   isco08   2010soc
# 0   0110  55-1011
# 1   0110  55-1012

# %%
file_name =  "files/CH_ISCO_19.xlsx"
sheet =  "CH_ISCO_19"

ch_isco = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=0, dtype=str)

# rename cols
ch_isco = ch_isco.rename(columns={'Berufsgattungen': 'isco08'})

# List of columns to drop
cols_to_drop = ['Berufshauptgruppen', 'Berufsgruppen', 'Berufsuntergruppen', "Berufsarten", "Code"]

# Drop specified columns
ch_isco = ch_isco.drop(columns=cols_to_drop)
ch_isco = ch_isco.dropna()
print(ch_isco.shape[0])

ch_isco.head(2)
# Out:
# 582
#   isco08                                    Name_de
# 3   0110       Offiziere in regulären Streitkräften
# 7   0210  Unteroffiziere in regulären Streitkräften

# %%
dbname = get_database()

collection_name = dbname["onet"]

data = collection_name.find()
onet = pd.DataFrame(list(data))
onet.head(2)
# Out:
#                         _id        code display  \
# 0  6620df94dde8b852bac8e7dd  13-2011.00    long
# 1  6620df94dde8b852bac8e7de  27-2011.00    long
#
#                                           occupation  \
# 0  {'code': '13-2011.00', 'title': 'Accountants a...
# 1  {'code': '27-2011.00', 'title': 'Actors', 'tag...
#
#                                                tasks  \
# 0  {'task': [{'id': 21505, 'green': False, 'relat...
# 1  {'task': [{'id': 7646, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'see_all': {'href': 'https://services.onetcen...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.1.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.7.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
# 1  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
# 1  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
# 1  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 4, 'title': 'Job Zone Four: Consider...
# 1  {'value': 2, 'title': 'Job Zone Two: Some Prep...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.f', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.c', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.5.b', 'related': 'htt...
# 1  {'element': [{'id': '1.C.3.a', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.a', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.d', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'https://www.aacsb.edu/', ...
# 1  {'source': [{'url': 'https://www.actorsequity....
#
#                                            education
# 0                                                NaN
# 1  {'level_required': {'category': [{'name': 'Les...
#
# [2 rows x 21 columns]

# %%
# Convert 'code' column to string
onet['code'] = onet['code'].astype(str)

# Rename 'code' column to 'onetsoc19'
onet = onet.rename(columns={'code': 'onetsoc19'})

print(onet.shape[0])

onet.head(2)
# Out:
# 1016
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7dd  13-2011.00    long
# 1  6620df94dde8b852bac8e7de  27-2011.00    long
#
#                                           occupation  \
# 0  {'code': '13-2011.00', 'title': 'Accountants a...
# 1  {'code': '27-2011.00', 'title': 'Actors', 'tag...
#
#                                                tasks  \
# 0  {'task': [{'id': 21505, 'green': False, 'relat...
# 1  {'task': [{'id': 7646, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'see_all': {'href': 'https://services.onetcen...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.1.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.7.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
# 1  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
# 1  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
# 1  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 4, 'title': 'Job Zone Four: Consider...
# 1  {'value': 2, 'title': 'Job Zone Two: Some Prep...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.f', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.c', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.5.b', 'related': 'htt...
# 1  {'element': [{'id': '1.C.3.a', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.a', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.d', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'https://www.aacsb.edu/', ...
# 1  {'source': [{'url': 'https://www.actorsequity....
#
#                                            education
# 0                                                NaN
# 1  {'level_required': {'category': [{'name': 'Les...
#
# [2 rows x 21 columns]

# %%
joined = pd.merge(onet, onetsoc_soc, left_on='onetsoc19', right_on="onetsoc19", how='left')

joined = joined.dropna()

# print amount of cols
print(joined.shape[0])

joined.head(2)
# Out:
# 851
#                         _id   onetsoc19 display  \
# 1  6620df94dde8b852bac8e7de  27-2011.00    long
# 2  6620df94dde8b852bac8e7df  15-2011.00    long
#
#                                           occupation  \
# 1  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 2  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 1  {'task': [{'id': 7646, 'green': False, 'relate...
# 2  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 1  {'category': [{'related': 'https://services.on...
# 2  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 1  {'category': [{'related': 'https://services.on...
# 2  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 1  {'tools': {'category': [{'related': 'https://s...
# 2  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 1  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 2  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  ...  \
# 1  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 2  {'element': [{'id': '2.A.2.a', 'related': 'htt...  ...
#
#                             detailed_work_activities  \
# 1  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
# 2  {'activity': [{'id': '4.A.4.b.4.I09.D06', 'rel...
#
#                                         work_context  \
# 1  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 2  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 1  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 2  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 1  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 2  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 1  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 2  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                          work_values  \
# 1  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 2  {'element': [{'id': '1.B.2.b', 'related': 'htt...
#
#                                  related_occupations  \
# 1  {'occupation': [{'href': 'https://services.one...
# 2  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 1  {'source': [{'url': 'https://www.actorsequity....
# 2  {'source': [{'url': 'https://www.actuary.org/'...
#
#                                            education  2010soc
# 1  {'level_required': {'category': [{'name': 'Les...  27-2011
# 2  {'level_required': {'category': [{'name': "Bac...  15-2011
#
# [2 rows x 22 columns]

# %%
joined = pd.merge(joined, isco_soc, left_on='2010soc', right_on="2010soc", how='left')

# print amount of cols
print(joined.shape[0])

joined.head(2)
# Out:
# 1065
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7df  15-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.2.a', 'related': 'htt...  ...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.b', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.actuary.org/'...
#
#                                            education  2010soc isco08
# 0  {'level_required': {'category': [{'name': 'Les...  27-2011   2655
# 1  {'level_required': {'category': [{'name': "Bac...  15-2011   2120
#
# [2 rows x 23 columns]

# %%
joined = pd.merge(joined, ch_isco, left_on='isco08', right_on="isco08", how='left')

# print amount of cols
print(joined.shape[0])

joined.head(2)
# Out:
# 1065
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7df  15-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.2.a', 'related': 'htt...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.b', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.actuary.org/'...
#
#                                            education  2010soc isco08  \
# 0  {'level_required': {'category': [{'name': 'Les...  27-2011   2655
# 1  {'level_required': {'category': [{'name': "Bac...  15-2011   2120
#
#                                  Name_de
# 0                           Schauspieler
# 1  Mathematiker, Aktuare und Statistiker
#
# [2 rows x 24 columns]

# %%
joined = joined.dropna()
joined = joined.drop(columns=["_id"])
print(joined.shape[0])
joined.head(2)
# Out:
# 846
#     onetsoc19 display                                         occupation  \
# 0  27-2011.00    long  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  15-2011.00    long  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...
# 1  {'element': [{'id': '2.A.2.a', 'related': 'htt...
#
#                                            abilities  ...  \
# 0  {'element': [{'id': '1.A.1.a.3', 'related': 'h...  ...
# 1  {'element': [{'id': '1.A.1.c.1', 'related': 'h...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.b', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.actuary.org/'...
#
#                                            education  2010soc isco08  \
# 0  {'level_required': {'category': [{'name': 'Les...  27-2011   2655
# 1  {'level_required': {'category': [{'name': "Bac...  15-2011   2120
#
#                                  Name_de
# 0                           Schauspieler
# 1  Mathematiker, Aktuare und Statistiker
#
# [2 rows x 23 columns]

# %%
dbname = get_database()

collection_name = dbname["joined"]

# Insert the dictionaries into the MongoDB collection
collection_name.insert_many(joined.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('6620dfe3e366d70e7b9073fc'), ObjectId('6620dfe3e366d70e7b9073fd'), ObjectId('6620dfe3e366d70e7b9073fe'), ObjectId('6620dfe3e366d70e7b9073ff'), ObjectId('6620dfe3e366d70e7b907400'), ObjectId('6620dfe3e366d70e7b907401'), ObjectId('6620dfe3e366d70e7b907402'), ObjectId('6620dfe3e366d70e7b907403'), ObjectId('6620dfe3e366d70e7b907404'), ObjectId('6620dfe3e366d70e7b907405'), ObjectId('6620dfe3e366d70e7b907406'), ObjectId('6620dfe3e366d70e7b907407'), ObjectId('6620dfe3e366d70e7b907408'), ObjectId('6620dfe3e366d70e7b907409'), ObjectId('6620dfe3e366d70e7b90740a'), ObjectId('6620dfe3e366d70e7b90740b'), ObjectId('6620dfe3e366d70e7b90740c'), ObjectId('6620dfe3e366d70e7b90740d'), ObjectId('6620dfe3e366d70e7b90740e'), ObjectId('6620dfe3e366d70e7b90740f'), ObjectId('6620dfe3e366d70e7b907410'), ObjectId('6620dfe3e366d70e7b907411'), ObjectId('6620dfe3e366d70e7b907412'), ObjectId('6620dfe3e366d70e7b907413'), ObjectId('6620dfe3e366d70e7b907414'), ObjectId('6620dfe3e366d70e7b907415'), ObjectId('6620dfe3e366d70e7b907416'), ObjectId('6620dfe3e366d70e7b907417'), ObjectId('6620dfe3e366d70e7b907418'), ObjectId('6620dfe3e366d70e7b907419'), ObjectId('6620dfe3e366d70e7b90741a'), ObjectId('6620dfe3e366d70e7b90741b'), ObjectId('6620dfe3e366d70e7b90741c'), ObjectId('6620dfe3e366d70e7b90741d'), ObjectId('6620dfe3e366d70e7b90741e'), ObjectId('6620dfe3e366d70e7b90741f'), ObjectId('6620dfe3e366d70e7b907420'), ObjectId('6620dfe3e366d70e7b907421'), ObjectId('6620dfe3e366d70e7b907422'), ObjectId('6620dfe3e366d70e7b907423'), ObjectId('6620dfe3e366d70e7b