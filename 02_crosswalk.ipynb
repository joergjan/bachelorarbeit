# %% [markdown]
# ### jupyter notebook to adjust the data from onet to the Swiss labour market
#
# author: Jan Jörg
# date: 14.03.2024

# %% [markdown]
# ###### onet soc to soc crosswalk: https://www.onetcenter.org/crosswalks.html
# ###### soc to isco08 crosswalk: https://www.bls.gov/soc/ISCO_SOC_Crosswalk.xls
# ###### ch isco 19: https://www.i14y.admin.ch/en/catalog/datasets/HCL_CH_ISCO_19_PROF_1_2/distributions

# %%
# imports
import pandas as pd
from db import get_database

# %%
onet_file =  "files/ONETSOC_SOC.xlsx"
sheet =  "ONETSOC_SOC"

onetsoc_soc = pd.read_excel(io=onet_file, sheet_name=sheet , skiprows=3, dtype=str)

# rename cols
onetsoc_soc = onetsoc_soc.rename(columns={'O*NET-SOC 2019 Code': 'onetsoc19'})
onetsoc_soc = onetsoc_soc.rename(columns={'2018 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['O*NET-SOC 2019 Title', '2018 SOC Title']

# Drop specified columns
onetsoc_soc = onetsoc_soc.drop(columns=cols_to_drop)
onetsoc_soc = onetsoc_soc.dropna()
print(onetsoc_soc.shape[0])

onetsoc_soc.head(2)
# Out:
# 1016
#     onetsoc19  2010soc
# 0  11-1011.00  11-1011
# 1  11-1011.03  11-1011

# %%
file_name =  "files/ISCO_SOC.xls"
sheet =  "ISCO_SOC"

isco_soc = pd.read_excel(io=file_name, sheet_name=sheet , skiprows=6, dtype=str)

# rename cols
isco_soc = isco_soc.rename(columns={'ISCO-08 Code': 'isco08'})
isco_soc = isco_soc.rename(columns={'2010 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['ISCO-08 Title EN', 'part', '2010 SOC Title', "Comment 8/17/11"]

# Drop specified columns
isco_soc = isco_soc.drop(columns=cols_to_drop)
isco_soc = isco_soc.dropna()
print(isco_soc.shape[0])

isco_soc.head(2)
# Out:
# 1125
#   isco08   2010soc
# 0   0110  55-1011
# 1   0110  55-1012

# %%
file_name =  "files/CH_ISCO_19.xlsx"
sheet =  "CH_ISCO_19"

ch_isco = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=0, dtype=str)

# rename cols
ch_isco = ch_isco.rename(columns={'Berufsgattungen': 'isco08'})

# List of columns to drop
cols_to_drop = ["Berufshauptgruppen",'Berufsgruppen', 'Berufsuntergruppen', "Berufsarten", "Code"]

# Drop specified columns
ch_isco = ch_isco.drop(columns=cols_to_drop)
ch_isco = ch_isco.dropna()
print(ch_isco.shape[0])

ch_isco.head(2)
# Out:
# 582
#   isco08                                    Name_de
# 3   0110       Offiziere in regulären Streitkräften
# 7   0210  Unteroffiziere in regulären Streitkräften

# %%
dbname = get_database()

collection_name = dbname["onet"]

data = collection_name.find()
onet = pd.DataFrame(list(data))
onet.head(2)
# Out:
#                         _id        code display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7dd  13-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '13-2011.00', 'title': 'Accountants a...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 21505, 'green': False, 'relat...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.1.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
# 1  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
# 1  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1                                                NaN
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.aacsb.edu/', ...
#
# [2 rows x 21 columns]

# %%
# import Source Frey / Osborne

fo =  pd.read_csv("files/FO.csv")

# %%
# Convert 'code' column to string
onet['code'] = onet['code'].astype(str)
fo["code"] = fo["code"].astype(str)

# Rename 'code' column to 'onetsoc19'
onet = onet.rename(columns={'code': 'onetsoc19'})
fo = fo.rename(columns={'code': '2010soc'})

print(onet.shape[0])
# Out:
# 1016

# %%
onet.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7dd  13-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '13-2011.00', 'title': 'Accountants a...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 21505, 'green': False, 'relat...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.1.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
# 1  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
# 1  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1                                                NaN
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.aacsb.edu/', ...
#
# [2 rows x 21 columns]

# %%
fo.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0   1.0       0.0028    na  29-1125
# 1   2.0       0.0030    na  49-1011
#
#                                           Occupation
# 0     Recreational TherapistsRecreational Therapists
# 1  First-Line Supervisors of MechanicsFirst-Line ...

# %%
# crosswalk onet soc

joined = pd.merge(onet, onetsoc_soc, left_on='onetsoc19', right_on="onetsoc19", how='left')

joined = joined.dropna()

# print amount of cols
print(joined.shape[0])
# Out:
# 851

# %%
# crosswalk soc

joined = pd.merge(joined, isco_soc, left_on='2010soc', right_on="2010soc", how='left')
fo_joined = pd.merge(fo, isco_soc, left_on='2010soc', right_on="2010soc", how='left')

# print amount of cols
print(joined.shape[0])
# Out:
# 1065

# %%
joined.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7e4  23-1021.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.2.a.1.a', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
# [2 rows x 23 columns]

# %%
fo_joined.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0   1.0       0.0028    na  29-1125
# 1   2.0       0.0030    na  49-1011
#
#                                           Occupation isco08
# 0     Recreational TherapistsRecreational Therapists    NaN
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127

# %%
# crosswalk isco08

joined = pd.merge(joined, ch_isco, left_on='isco08', right_on="isco08", how='left')
fo_joined = pd.merge(fo_joined, ch_isco, left_on='isco08', right_on="isco08", how='left')

# print amount of cols
print(joined.shape[0])
print(fo_joined.shape[0])
# Out:
# 1065
# 803

# %%
joined.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7e4  23-1021.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08  \
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
#         Name_de
# 0  Schauspieler
# 1       Richter
#
# [2 rows x 24 columns]

# %%
fo_joined.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0   1.0       0.0028    na  29-1125
# 1   2.0       0.0030    na  49-1011
#
#                                           Occupation isco08  \
# 0     Recreational TherapistsRecreational Therapists    NaN
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127
#
#                                    Name_de
# 0                                      NaN
# 1  Klima-, Kälte, und Lüftungsanlagenbauer

# %%
joined = joined.dropna()
joined = joined.drop(columns=["_id"])
fo_joined = fo_joined.dropna()
print(joined.shape[0])
joined.head(2)
# Out:
# 846
#     onetsoc19 display                                         occupation  \
# 0  27-2011.00    long  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  23-1021.00    long  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...
#
#                                            abilities  ...  \
# 0  {'element': [{'id': '1.A.1.a.3', 'related': 'h...  ...
# 1  {'element': [{'id': '1.A.1.b.5', 'related': 'h...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08  \
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
#         Name_de
# 0  Schauspieler
# 1       Richter
#
# [2 rows x 23 columns]

# %%
fo_joined.head(5)
# Out:
#    Rank  Probability Label  2010soc  \
# 1   2.0        0.003    na  49-1011
# 2   2.0        0.003    na  49-1011
# 3   2.0        0.003    na  49-1011
# 4   2.0        0.003    na  49-1011
# 5   2.0        0.003    na  49-1011
#
#                                           Occupation isco08  \
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127
# 2  First-Line Supervisors of MechanicsFirst-Line ...   7231
# 3  First-Line Supervisors of MechanicsFirst-Line ...   7232
# 4  First-Line Supervisors of MechanicsFirst-Line ...   7233
# 5  First-Line Supervisors of MechanicsFirst-Line ...   7234
#
#                                              Name_de
# 1            Klima-, Kälte, und Lüftungsanlagenbauer
# 2             Kraftfahrzeugmechaniker und -schlosser
# 3               Flugmotorenmechaniker und -schlosser
# 4  Landmaschinen- und Industriemaschinenmechanike...
# 5             Fahrradmechaniker und verwandte Berufe

# %%
joined = joined.drop(columns=["onetsoc19","2010soc"])
fo_joined = fo_joined.drop(columns=["2010soc","Occupation","Name_de","Rank"])
fo_joined = fo_joined.rename(columns={'Label': 'fo_computerisation',"Probability":"fo_probability"})

# %%
fo_joined.head(2)
# Out:
#    fo_probability fo_computerisation isco08
# 1           0.003                 na   7127
# 2           0.003                 na   7231

# %%
joined.head(5)
# Out:
#   display                                         occupation  \
# 0    long  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1    long  {'code': '23-1021.00', 'title': 'Administrativ...
# 2    long  {'code': '17-3021.00', 'title': 'Aerospace Eng...
# 3    long  {'code': '15-2011.00', 'title': 'Actuaries', '...
# 4    long  {'code': '11-2011.00', 'title': 'Advertising a...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
# 2  {'task': [{'id': 10888, 'green': False, 'relat...
# 3  {'task': [{'id': 3500, 'green': False, 'relate...
# 4  {'task': [{'id': 3224, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
# 2  {'see_all': {'href': 'https://services.onetcen...
# 3  {'see_all': {'href': 'https://services.onetcen...
# 4  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
# 2  {'see_all': {'href': 'https://services.onetcen...
# 3  {'category': [{'related': 'https://services.on...
# 4  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
# 2  {'tools': {'see_all': {'href': 'https://servic...
# 3  {'tools': {'category': [{'related': 'https://s...
# 4  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
# 2  {'element': [{'id': '2.C.3.e', 'related': 'htt...
# 3  {'element': [{'id': '2.C.4.a', 'related': 'htt...
# 4  {'element': [{'id': '2.C.1.d', 'related': 'htt...
#
#                                               skills  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...
# 2  {'element': [{'id': '2.A.2.a', 'related': 'htt...
# 3  {'element': [{'id': '2.A.2.a', 'related': 'htt...
# 4  {'element': [{'id': '2.A.1.b', 'related': 'htt...
#
#                                            abilities  \
# 0  {'element': [{'id': '1.A.1.a.3', 'related': 'h...
# 1  {'element': [{'id': '1.A.1.b.5', 'related': 'h...
# 2  {'element': [{'id': '1.A.1.a.1', 'related': 'h...
# 3  {'element': [{'id': '1.A.1.c.1', 'related': 'h...
# 4  {'element': [{'id': '1.A.1.a.3', 'related': 'h...
#
#                                      work_activities  ...  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...  ...
# 1  {'element': [{'id': '4.A.2.b.1', 'related': 'h...  ...
# 2  {'element': [{'id': '4.A.1.a.1', 'related': 'h...  ...
# 3  {'element': [{'id': '4.A.2.a.4', 'related': 'h...  ...
# 4  {'element': [{'id': '4.A.3.b.1', 'related': 'h...  ...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.2.a.1.a', 'related': ...
# 2  {'element': [{'id': '4.C.3.b.4', 'related': 'h...
# 3  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
# 4  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
# 2  {'value': 3, 'title': 'Job Zone Three: Medium ...
# 3  {'value': 4, 'title': 'Job Zone Four: Consider...
# 4  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
# 2  {'level_required': {'category': [{'name': 'Pos...
# 3  {'level_required': {'category': [{'name': "Bac...
# 4  {'level_required': {'category': [{'name': "Bac...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
# 2  {'element': [{'id': '1.B.1.a', 'related': 'htt...
# 3  {'element': [{'id': '1.B.1.f', 'related': 'htt...
# 4  {'element': [{'id': '1.B.1.e', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
# 2  {'element': [{'id': '1.C.5.b', 'related': 'htt...
# 3  {'element': [{'id': '1.C.7.b', 'related': 'htt...
# 4  {'element': [{'id': '1.C.1.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
# 2  {'element': [{'id': '1.B.2.e', 'related': 'htt...
# 3  {'element': [{'id': '1.B.2.b', 'related': 'htt...
# 4  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
# 2  {'occupation': [{'href': 'https://services.one...
# 3  {'occupation': [{'href': 'https://services.one...
# 4  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information isco08  \
# 0  {'source': [{'url': 'https://www.actorsequity....   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...   2612
# 2  {'source': [{'url': 'https://www.aiaa.org/', '...   3115
# 3  {'source': [{'url': 'https://www.actuary.org/'...   2120
# 4  {'source': [{'url': 'https://www.adcouncil.org...   1222
#
#                                              Name_de
# 0                                       Schauspieler
# 1                                            Richter
# 2  Maschinenbautechniker, Techniker im Bereich Sy...
# 3              Mathematiker, Aktuare und Statistiker
# 4  Führungskräfte in Werbung und Öffentlichkeitsa...
#
# [5 rows x 21 columns]

# %%
#dbname = get_database()

collection_name = dbname["joined"]
fo_col = dbname["fo_joined"]

# Insert the dictionaries into the MongoDB collection
collection_name.insert_many(joined.to_dict("records"))
fo_col.insert_many(fo_joined.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('663e2380db2fdc9e602a9498'), ObjectId('663e2380db2fdc9e602a9499'), ObjectId('663e2380db2fdc9e602a949a'), ObjectId('663e2380db2fdc9e602a949b'), ObjectId('663e2380db2fdc9e602a949c'), ObjectId('663e2380db2fdc9e602a949d'), ObjectId('663e2380db2fdc9e602a949e'), ObjectId('663e2380db2fdc9e602a949f'), ObjectId('663e2380db2fdc9e602a94a0'), ObjectId('663e2380db2fdc9e602a94a1'), ObjectId('663e2380db2fdc9e602a94a2'), ObjectId('663e2380db2fdc9e602a94a3'), ObjectId('663e2380db2fdc9e602a94a4'), ObjectId('663e2380db2fdc9e602a94a5'), ObjectId('663e2380db2fdc9e602a94a6'), ObjectId('663e2380db2fdc9e602a94a7'), ObjectId('663e2380db2fdc9e602a94a8'), ObjectId('663e2380db2fdc9e602a94a9'), ObjectId('663e2380db2fdc9e602a94aa'), ObjectId('663e2380db2fdc9e602a94ab'), ObjectId('663e2380db2fdc9e602a94ac'), ObjectId('663e2380db2fdc9e602a94ad'), ObjectId('663e2380db2fdc9e602a94ae'), ObjectId('663e2380db2fdc9e602a94af'), ObjectId('663e2380db2fdc9e602a94b0'), ObjectId('663e2380db2fdc9e602a94b1'), ObjectId('663e2380db2fdc9e602a94b2'), ObjectId('663e2380db2fdc9e602a94b3'), ObjectId('663e2380db2fdc9e602a94b4'), ObjectId('663e2380db2fdc9e602a94b5'), ObjectId('663e2380db2fdc9e602a94b6'), ObjectId('663e2380db2fdc9e602a94b7'), ObjectId('663e2380db2fdc9e602a94b8'), ObjectId('663e2380db2fdc9e602a94b9'), ObjectId('663e2380db2fdc9e602a94ba'), ObjectId('663e2380db2fdc9e602a94bb'), ObjectId('663e2380db2fdc9e602a94bc'), ObjectId('663e2380db2fdc9e602a94bd'), ObjectId('663e2380db2fdc9e602a94be'), ObjectId('663e2380db2fdc9e602a94bf'), ObjectId('663e2380db2fdc9e602a94c0'), ObjectId('663e2380db2fdc9e602a94c1'), ObjectId('663e2380db2fdc9e602a94c2'), ObjectId('663e2380db2fdc9e602a94c3'), ObjectId('663e2380db2fdc9e602a94c4'), ObjectId('663e2380db2fdc9e602a94c5'), ObjectId('663e2380db2fdc9e602a94c6'), ObjectId('663e2380db2fdc9e602a94c7'), ObjectId('663e2380db2fdc9e602a94c8'), ObjectId('663e2380db2fdc9e602a94c9'), ObjectId('663e2380db2fdc9e602a94ca'), ObjectId('663e2380db2fdc9e602a94cb'), ObjectId('663e2380db2fdc9e602a94cc'), ObjectId('663e2380db2fdc9e602a94cd'), ObjectId('663e2380db2fdc9e602a94ce'), ObjectId('663e2380db2fdc9e602a94cf'), ObjectId('663e2380db2fdc9e602a94d0'), ObjectId('663e2380db2fdc9e602a94d1'), ObjectId('663e2380db2fdc9e602a94d2'), ObjectId('663e2380db2fdc9e602a94d3'), ObjectId('663e2380db2fdc9e602a94d4'), ObjectId('663e2380db2fdc9e602a94d5'), ObjectId('663e2380db2fdc9e602a94d6'), ObjectId('663e2380db2fdc9e602a94d7'), ObjectId('663e2380db2fdc9e602a94d8'), ObjectId('663e2380db2fdc9e602a94d9'), ObjectId('663e2380db2fdc9e602a94da'), ObjectId('663e2380db2fdc9e602a94db'), ObjectId('663e2380db2fdc9e602a94dc'), ObjectId('663e2380db2fdc9e602a94dd'), ObjectId('663e2380db2fdc9e602a94de'), ObjectId('663e2380db2fdc9e602a94df'), ObjectId('663e2380db2fdc9e602a94e0'), ObjectId('663e2380db2fdc9e602a94e1'), ObjectId('663e2380db2fdc9e602a94e2'), ObjectId('663e2380db2fdc9e602a94e3'), ObjectId('663e2380db2fdc9e602a94e4'), ObjectId('663e2380db2fdc9e602a94e5'), ObjectId('663e2380db2fdc9e602a94e6'), ObjectId('663e2380db2fdc9e602a94e7'), ObjectId('663e2380db2fdc9e602a94e8'), ObjectId('663e2380db2fdc9e602a94e9'), ObjectId('663e2380db2fdc9e602a94ea'), ObjectId('663e2380db2fdc9e602a94eb'), ObjectId('663e2380db2fdc9e602a94ec'), ObjectId('663e2380db2fdc9e602a94ed'), ObjectId('663e2380db2fdc9e602a94ee'), ObjectId('663e2380db2fdc9e602a94ef'), ObjectId('663e2380db2fdc9e602a94f0'), ObjectId('663e2380db2fdc9e602a94f1'), ObjectId('663e2380db2fdc9e602a94f2'), ObjectId('663e2380db2fdc9e602a94f3'), ObjectId('663e2380db2fdc9e602a94f4'), ObjectId('663e2380db2fdc9e602a94f5'), ObjectId('663e2380db2fdc9e602a94f6'), ObjectId('663e2380db2fdc9e602a94f7'), ObjectId('663e2380db2fdc9e602a94f8'), ObjectId('663e2380db2fdc9e602a94f9'), ObjectId('663e2380db2fdc9e602a94fa'), ObjectId('663e2380db2fdc9e602a94fb'), ObjectId('663e2380db2fdc9e602a94fc'), ObjectId('663e2380db2fdc9e602a94fd'), ObjectId('663e2380db2fdc9e602a94fe'), ObjectId('663e2380db2fdc9e602a94ff'), ObjectId('663e2380db2fdc9e602a ...
