# %% [markdown]
# ### jupyter notebook to adjust the data from onet to the Swiss labour market
#
# author: Jan Jörg
# date: 14.03.2024

# %% [markdown]
# ###### onet soc to soc crosswalk: https://www.onetcenter.org/crosswalks.html
# ###### soc to isco08 crosswalk: https://www.bls.gov/soc/ISCO_SOC_Crosswalk.xls
# ###### ch isco 19: https://www.i14y.admin.ch/en/catalog/datasets/HCL_CH_ISCO_19_PROF_1_2/distributions

# %%
# imports
import pandas as pd
from db import get_database

# %%
onet_file =  "files/ONETSOC_SOC.xlsx"
sheet =  "ONETSOC_SOC"

onetsoc_soc = pd.read_excel(io=onet_file, sheet_name=sheet , skiprows=3, dtype=str)

# rename cols
onetsoc_soc = onetsoc_soc.rename(columns={'O*NET-SOC 2019 Code': 'onetsoc19'})
onetsoc_soc = onetsoc_soc.rename(columns={'2018 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['O*NET-SOC 2019 Title', '2018 SOC Title']

# Drop specified columns
onetsoc_soc = onetsoc_soc.drop(columns=cols_to_drop)
onetsoc_soc = onetsoc_soc.dropna()
print(onetsoc_soc.shape[0])

onetsoc_soc.head(2)
# Out:
# 1016
#     onetsoc19  2010soc
# 0  11-1011.00  11-1011
# 1  11-1011.03  11-1011

# %%
file_name =  "files/ISCO_SOC.xls"
sheet =  "ISCO_SOC"

isco_soc = pd.read_excel(io=file_name, sheet_name=sheet , skiprows=6, dtype=str)

# rename cols
isco_soc = isco_soc.rename(columns={'ISCO-08 Code': 'isco08'})
isco_soc = isco_soc.rename(columns={'2010 SOC Code': '2010soc'})

# List of columns to drop
cols_to_drop = ['ISCO-08 Title EN', 'part', '2010 SOC Title', "Comment 8/17/11"]

# Drop specified columns
isco_soc = isco_soc.drop(columns=cols_to_drop)
isco_soc = isco_soc.dropna()
print(isco_soc.shape[0])

isco_soc.head(2)
# Out:
# 1125
#   isco08   2010soc
# 0   0110  55-1011
# 1   0110  55-1012

# %%
file_name =  "files/CH_ISCO_19.xlsx"
sheet =  "CH_ISCO_19"

ch_isco = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=0, dtype=str)

# rename cols
ch_isco = ch_isco.rename(columns={'Berufsgattungen': 'isco08'})

# List of columns to drop
cols_to_drop = ['Berufshauptgruppen', 'Berufsgruppen', 'Berufsuntergruppen', "Berufsarten", "Code"]

# Drop specified columns
ch_isco = ch_isco.drop(columns=cols_to_drop)
ch_isco = ch_isco.dropna()
print(ch_isco.shape[0])

ch_isco.head(2)
# Out:
# 582
#   isco08                                    Name_de
# 3   0110       Offiziere in regulären Streitkräften
# 7   0210  Unteroffiziere in regulären Streitkräften

# %%
dbname = get_database()

collection_name = dbname["onet"]

data = collection_name.find()
onet = pd.DataFrame(list(data))
onet.head(2)
# Out:
#                         _id        code display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7dd  13-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '13-2011.00', 'title': 'Accountants a...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 21505, 'green': False, 'relat...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.1.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
# 1  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
# 1  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1                                                NaN
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.aacsb.edu/', ...
#
# [2 rows x 21 columns]

# %%
# import Source Frey / Osborne

fo =  pd.read_csv("files/FO.csv")

# %%
# Convert 'code' column to string
onet['code'] = onet['code'].astype(str)
fo["code"] = fo["code"].astype(str)

# Rename 'code' column to 'onetsoc19'
onet = onet.rename(columns={'code': 'onetsoc19'})
fo = fo.rename(columns={'code': '2010soc'})

print(onet.shape[0])
# Out:
# 1016

# %%
onet.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7dd  13-2011.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '13-2011.00', 'title': 'Accountants a...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 21505, 'green': False, 'relat...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'see_all': {'href': 'https://services.onetcen...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.1.c', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
# 1  {'element': [{'id': '4.A.1.a.1', 'related': 'h...
#
#                             detailed_work_activities  \
# 0  {'activity': [{'id': '4.A.4.a.8.I01.D04', 'rel...
# 1  {'activity': [{'id': '4.A.3.b.6.I01.D02', 'rel...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1                                                NaN
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information
# 0  {'source': [{'url': 'https://www.actorsequity....
# 1  {'source': [{'url': 'https://www.aacsb.edu/', ...
#
# [2 rows x 21 columns]

# %%
fo.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0     1         28.0     a  29-1125
# 1     2          3.0     a  49-1011
#
#                                           Occupation
# 0     Recreational TherapistsRecreational Therapists
# 1  First-Line Supervisors of MechanicsFirst-Line ...

# %%
# crosswalk onet soc

joined = pd.merge(onet, onetsoc_soc, left_on='onetsoc19', right_on="onetsoc19", how='left')

joined = joined.dropna()

# print amount of cols
print(joined.shape[0])
# Out:
# 851

# %%
# crosswalk soc

joined = pd.merge(joined, isco_soc, left_on='2010soc', right_on="2010soc", how='left')
fo_joined = pd.merge(fo, isco_soc, left_on='2010soc', right_on="2010soc", how='left')

# print amount of cols
print(joined.shape[0])
# Out:
# 1065

# %%
joined.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7e4  23-1021.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.2.a.1.a', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
# [2 rows x 23 columns]

# %%
fo_joined.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0     1         28.0     a  29-1125
# 1     2          3.0     a  49-1011
#
#                                           Occupation isco08
# 0     Recreational TherapistsRecreational Therapists    NaN
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127

# %%
# crosswalk isco08

joined = pd.merge(joined, ch_isco, left_on='isco08', right_on="isco08", how='left')
fo_joined = pd.merge(fo_joined, ch_isco, left_on='isco08', right_on="isco08", how='left')

# print amount of cols
print(joined.shape[0])
# Out:
# 1065

# %%
joined.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  6620df94dde8b852bac8e7de  27-2011.00    long
# 1  6620df94dde8b852bac8e7e4  23-1021.00    long
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08  \
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
#         Name_de
# 0  Schauspieler
# 1       Richter
#
# [2 rows x 24 columns]

# %%
fo_joined.head(2)
# Out:
#    Rank  Probability Label  2010soc  \
# 0     1         28.0     a  29-1125
# 1     2          3.0     a  49-1011
#
#                                           Occupation isco08  \
# 0     Recreational TherapistsRecreational Therapists    NaN
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127
#
#                                    Name_de
# 0                                      NaN
# 1  Klima-, Kälte, und Lüftungsanlagenbauer

# %%
joined = joined.dropna()
joined = joined.drop(columns=["_id"])
fo_joined = fo_joined.dropna()
print(joined.shape[0])
joined.head(2)
# Out:
# 846
#     onetsoc19 display                                         occupation  \
# 0  27-2011.00    long  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  23-1021.00    long  {'code': '23-1021.00', 'title': 'Administrativ...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 7627, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.8.b', 'related': 'htt...
#
#                                               skills  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...
# 1  {'element': [{'id': '2.A.1.b', 'related': 'htt...
#
#                                            abilities  ...  \
# 0  {'element': [{'id': '1.A.1.a.3', 'related': 'h...  ...
# 1  {'element': [{'id': '1.A.1.b.5', 'related': 'h...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 5, 'title': 'Job Zone Five: Extensiv...
#
#                                            education  \
# 0  {'level_required': {'category': [{'name': 'Les...
# 1  {'level_required': {'category': [{'name': 'Doc...
#
#                                            interests  \
# 0  {'element': [{'id': '1.B.1.c', 'related': 'htt...
# 1  {'element': [{'id': '1.B.1.f', 'related': 'htt...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.5.c', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.a', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  2010soc isco08  \
# 0  {'source': [{'url': 'https://www.actorsequity....  27-2011   2655
# 1  {'source': [{'url': 'https://www.americanbar.o...  23-1021   2612
#
#         Name_de
# 0  Schauspieler
# 1       Richter
#
# [2 rows x 23 columns]

# %%
fo_joined.head(5)
# Out:
#    Rank  Probability Label  2010soc  \
# 1     2          3.0     a  49-1011
# 2     2          3.0     a  49-1011
# 3     2          3.0     a  49-1011
# 4     2          3.0     a  49-1011
# 5     2          3.0     a  49-1011
#
#                                           Occupation isco08  \
# 1  First-Line Supervisors of MechanicsFirst-Line ...   7127
# 2  First-Line Supervisors of MechanicsFirst-Line ...   7231
# 3  First-Line Supervisors of MechanicsFirst-Line ...   7232
# 4  First-Line Supervisors of MechanicsFirst-Line ...   7233
# 5  First-Line Supervisors of MechanicsFirst-Line ...   7234
#
#                                              Name_de
# 1            Klima-, Kälte, und Lüftungsanlagenbauer
# 2             Kraftfahrzeugmechaniker und -schlosser
# 3               Flugmotorenmechaniker und -schlosser
# 4  Landmaschinen- und Industriemaschinenmechanike...
# 5             Fahrradmechaniker und verwandte Berufe

# %%
dbname = get_database()

collection_name = dbname["joined"]
fo_name = dbname["fo_joined"]

# Insert the dictionaries into the MongoDB collection
collection_name.insert_many(joined.to_dict("records"))
fo_name.insert_many(fo_joined.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('663deefbdb2fdc9e602a1e09'), ObjectId('663deefbdb2fdc9e602a1e0a'), ObjectId('663deefbdb2fdc9e602a1e0b'), ObjectId('663deefbdb2fdc9e602a1e0c'), ObjectId('663deefbdb2fdc9e602a1e0d'), ObjectId('663deefbdb2fdc9e602a1e0e'), ObjectId('663deefbdb2fdc9e602a1e0f'), ObjectId('663deefbdb2fdc9e602a1e10'), ObjectId('663deefbdb2fdc9e602a1e11'), ObjectId('663deefbdb2fdc9e602a1e12'), ObjectId('663deefbdb2fdc9e602a1e13'), ObjectId('663deefbdb2fdc9e602a1e14'), ObjectId('663deefbdb2fdc9e602a1e15'), ObjectId('663deefbdb2fdc9e602a1e16'), ObjectId('663deefbdb2fdc9e602a1e17'), ObjectId('663deefbdb2fdc9e602a1e18'), ObjectId('663deefbdb2fdc9e602a1e19'), ObjectId('663deefbdb2fdc9e602a1e1a'), ObjectId('663deefbdb2fdc9e602a1e1b'), ObjectId('663deefbdb2fdc9e602a1e1c'), ObjectId('663deefbdb2fdc9e602a1e1d'), ObjectId('663deefbdb2fdc9e602a1e1e'), ObjectId('663deefbdb2fdc9e602a1e1f'), ObjectId('663deefbdb2fdc9e602a1e20'), ObjectId('663deefbdb2fdc9e602a1e21'), ObjectId('663deefbdb2fdc9e602a1e22'), ObjectId('663deefbdb2fdc9e602a1e23'), ObjectId('663deefbdb2fdc9e602a1e24'), ObjectId('663deefbdb2fdc9e602a1e25'), ObjectId('663deefbdb2fdc9e602a1e26'), ObjectId('663deefbdb2fdc9e602a1e27'), ObjectId('663deefbdb2fdc9e602a1e28'), ObjectId('663deefbdb2fdc9e602a1e29'), ObjectId('663deefbdb2fdc9e602a1e2a'), ObjectId('663deefbdb2fdc9e602a1e2b'), ObjectId('663deefbdb2fdc9e602a1e2c'), ObjectId('663deefbdb2fdc9e602a1e2d'), ObjectId('663deefbdb2fdc9e602a1e2e'), ObjectId('663deefbdb2fdc9e602a1e2f'), ObjectId('663deefbdb2fdc9e602a1e30'), ObjectId('663deefbdb2fdc9e602a1e31'), ObjectId('663deefbdb2fdc9e602a1e32'), ObjectId('663deefbdb2fdc9e602a1e33'), ObjectId('663deefbdb2fdc9e602a1e34'), ObjectId('663deefbdb2fdc9e602a1e35'), ObjectId('663deefbdb2fdc9e602a1e36'), ObjectId('663deefbdb2fdc9e602a1e37'), ObjectId('663deefbdb2fdc