# %% [markdown]
# ### jupyter notebook to clean up data from onet
#
# author: Jan Jörg
# date: 14.03.2024

# %%
import json
from db import get_database
import pandas as pd
import numpy as np

# %%
# import authentication data

with open('./infos.json') as f:
    infos = json.load(f)
    onet = infos['onet']
    onetUsername = onet['username']
    onetPassword = onet['password']
    mongodb = infos['mongodb']
    mongoUusername = mongodb['username']
    mongoPpassword = mongodb['password']
    mongoUrl = mongodb['connectionString']

# %%
dbname = get_database()
collection = dbname["joined"]

documents = collection.find()
df = pd.DataFrame(list(documents))

df.head(2)
# Out:
#                         _id   onetsoc19 display  \
# 0  661d1a30d05f1cef398e0e97  27-2011.00   short
# 1  661d1a30d05f1cef398e0e98  15-2011.00   short
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  ...  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...  ...
# 1  {'element': [{'id': '2.A.2.a', 'related': 'htt...  ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 0  {'high_point_code': 'ASE', 'element': [{'id': ...
# 1  {'high_point_code': 'CIE', 'element': [{'id': ...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                          work_values  \
# 0  {'element': [{'id': '1.B.2.d', 'related': 'htt...
# 1  {'element': [{'id': '1.B.2.b', 'related': 'htt...
#
#                                  related_occupations  \
# 0  {'occupation': [{'href': 'https://services.one...
# 1  {'occupation': [{'href': 'https://services.one...
#
#                               additional_information  \
# 0  {'source': [{'url': 'http://www.actorsequity.o...
# 1  {'source': [{'url': 'https://www.actuary.org/'...
#
#                                            education  2010soc isco08  \
# 0  {'level_required': {'category': [{'name': 'Les...  27-2011   2655
# 1  {'level_required': {'category': [{'name': "Bac...  15-2011   2120
#
#                                  Name_de
# 0                           Schauspieler
# 1  Mathematiker, Aktuare und Statistiker
#
# [2 rows x 24 columns]

# %%
# Remove empty cols
print("Total documents: ", len(df))

# Drop columns where some values are null
df = df.dropna(how='all', axis=1)

# Drop rows where all some are null
df = df.dropna(how='all', axis=0)

# Replace any remaining NaN values with 0
df = df.fillna(0)

print("Total documents after dropping na: ", len(df))
# Out:
# Total documents:  846
# Total documents after dropping na:  846

# %%
# Remove columns that are not useful
df = df.drop(['additional_information',"related_occupations","work_values","display",'detailed_work_activities',"onetsoc19","2010soc"], axis=1)
df.head(2)
# Out:
#                         _id  \
# 0  661d1a30d05f1cef398e0e97
# 1  661d1a30d05f1cef398e0e98
#
#                                           occupation  \
# 0  {'code': '27-2011.00', 'title': 'Actors', 'tag...
# 1  {'code': '15-2011.00', 'title': 'Actuaries', '...
#
#                                                tasks  \
# 0  {'task': [{'id': 7646, 'green': False, 'relate...
# 1  {'task': [{'id': 3500, 'green': False, 'relate...
#
#                                    technology_skills  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                           tools_used  \
# 0  {'category': [{'related': 'https://services.on...
# 1  {'category': [{'related': 'https://services.on...
#
#                                     tools_technology  \
# 0  {'tools': {'category': [{'related': 'https://s...
# 1  {'tools': {'category': [{'related': 'https://s...
#
#                                            knowledge  \
# 0  {'element': [{'id': '2.C.7.c', 'related': 'htt...
# 1  {'element': [{'id': '2.C.4.a', 'related': 'htt...
#
#                                               skills  \
# 0  {'element': [{'id': '2.A.1.a', 'related': 'htt...
# 1  {'element': [{'id': '2.A.2.a', 'related': 'htt...
#
#                                            abilities  \
# 0  {'element': [{'id': '1.A.1.a.3', 'related': 'h...
# 1  {'element': [{'id': '1.A.1.c.1', 'related': 'h...
#
#                                      work_activities  \
# 0  {'element': [{'id': '4.A.4.a.4', 'related': 'h...
# 1  {'element': [{'id': '4.A.2.a.4', 'related': 'h...
#
#                                         work_context  \
# 0  {'element': [{'id': '4.C.1.b.1.e', 'related': ...
# 1  {'element': [{'id': '4.C.1.a.2.h', 'related': ...
#
#                                             job_zone  \
# 0  {'value': 2, 'title': 'Job Zone Two: Some Prep...
# 1  {'value': 4, 'title': 'Job Zone Four: Consider...
#
#                                            interests  \
# 0  {'high_point_code': 'ASE', 'element': [{'id': ...
# 1  {'high_point_code': 'CIE', 'element': [{'id': ...
#
#                                          work_styles  \
# 0  {'element': [{'id': '1.C.3.a', 'related': 'htt...
# 1  {'element': [{'id': '1.C.7.b', 'related': 'htt...
#
#                                            education  2010soc isco08  \
# 0  {'level_required': {'category': [{'name': 'Les...  27-2011   2655
# 1  {'level_required': {'category': [{'name': "Bac...  15-2011   2120
#
#                                  Name_de
# 0                           Schauspieler
# 1  Mathematiker, Aktuare und Statistiker

# %%
occupation = pd.DataFrame(list(df["occupation"])) 

# List of columns to drop
cols_to_drop = ["code","updated","sample_of_reported_job_titles","summary_resources","details_resources","custom_resources", "tags"]

# Drop the columns
occupation = occupation.drop(cols_to_drop, axis=1)

df = pd.concat([df.drop('occupation', axis=1), occupation], axis=1)

occupation.head(2)
# Out:
#        title                                        description  \
# 0     Actors  Play parts in stage, television, radio, video,...
# 1  Actuaries  Analyze statistical data, such as mortality, a...
#
#                                       bright_outlook also_see
# 0                                                NaN      NaN
# 1  {'description': 'This occupation is expected t...      NaN

# %%
tasks = pd.DataFrame(list(df["tasks"]))

cols_to_drop = [""]

tasks = tasks.drop(cols_to_drop, axis=1)
df = pd.concat([df.drop('occupation', axis=1), tasks], axis=1)

tasks.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 5
#       1 tasks = pd.DataFrame(list(df["tasks"]))
#       3 cols_to_drop = [""]
# ----> 5 tasks = tasks.drop(cols_to_drop, axis=1)
#       6 df = pd.concat([df.drop('occupation', axis=1), tasks], axis=1)
#       8 tasks.head(2)
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "[''] not found in axis"

# %%
#technology_skills
#tools_used
#tools_technology
#knowledge
#skills
#abilities
#work_activities
#work_context
#job_zone
#interests
#work_styles

# %%
print(df["occupation"].head(5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'occupation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 print(df["occupation"].head(5))
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/envs/bachelorarbeit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'occupation'
